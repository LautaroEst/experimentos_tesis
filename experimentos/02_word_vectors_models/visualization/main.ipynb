# %%
from utils import svd_2d_visualization, name2file
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
with open("words_to_visualize.txt") as f:
    words_to_visualize = [line.split("\n")[0] for line in f.readlines()]

print("Modelos para visualizar:")
print(sorted([name for name in name2file.keys()]))
print()
print("Palabras a visualizar:")
print(words_to_visualize)
# Out:
# Modelos para visualizar:
# ['melisa_wbc_n2', 'melisa_wbc_n3', 'melisa_wbc_n5', 'melisa_wbc_ppmi_n2', 'melisa_wbc_ppmi_n3', 'melisa_wbc_ppmi_n5', 'melisa_wbc_tfidf_n2', 'melisa_wbc_tfidf_n3', 'melisa_wbc_tfidf_n5', 'melisa_wbw_w16', 'melisa_wbw_w16_ppmi', 'melisa_wbw_w16_tfidf', 'melisa_wbw_w2', 'melisa_wbw_w2_ppmi', 'melisa_wbw_w2_tfidf', 'melisa_wbw_w4', 'melisa_wbw_w4_ppmi', 'melisa_wbw_w4_tfidf', 'melisa_wbw_w8', 'melisa_wbw_w8_ppmi', 'melisa_wbw_w8_tfidf', 'sbwc_fasttext300', 'sbwc_glove300', 'sbwc_word2vec300']
#
# Palabras a visualizar:
# ['bueno', 'buen', 'buenísimo', 'bien', 'malo', 'mal', 'malísimo', 'trucho', 'berreta', 'él', 'ella', 'ellos', 'ellas', 'mucho', 'todo', 'algo', 'nada', 'tanto', 'poco', 'cuánto', 'cuando', 'cómo', 'quién', 'qué', 'sí', 'no', 'maso']

# %%
fig, ax = svd_2d_visualization(name2file["melisa_wbw_w16"],words=words_to_visualize)
ax.grid(True)
# Out:
# Loading embeddings...
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = svd_2d_visualization(name2file["melisa_wbw_w16_tfidf"],words=words_to_visualize)
ax.grid(True)
# Out:
# Loading embeddings...
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = svd_2d_visualization(name2file["melisa_wbw_w16_ppmi"],words=words_to_visualize)
ax.grid(True)
# Out:
# Loading embeddings...
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = svd_2d_visualization(name2file["melisa_wbc_ppmi_n5"],words=words_to_visualize)
ax.grid(True)
# Out:
# Loading embeddings...
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = svd_2d_visualization(name2file["sbwc_glove300"],words=words_to_visualize)
ax.grid(True)
# Out:
# Loading embeddings...
# <img src="data:image/png;base64,..." width="900">
